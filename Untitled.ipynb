# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Value': [10, 15, 7, 12, 18, 5]
})

# Create a categorical plot
sns.catplot(x='Category', y='Value', kind='bar', data=data)

# Show the plot
plt.title("🎨 Seaborn Categorical Plot")
plt.show()
# Out:
# C:\Users\Navneet\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
